# %% [markdown]
# # 01 — Data Exploration
#
# Goals:
# - Inspect raw files in `data/raw/`
# - Confirm internal HDF5 layout (keys, shapes, compression filters)
# - Load a *sample* of events safely (no full-file load)
# - Produce diagnostic plots to understand distributions and correlations
#
# Notes:
# - LHCO2020 files in this repo are stored as a pandas-style HDF5 with the main matrix at `df/block0_values` of shape `(N_events, 2100)`.
# - The payload is compressed with the HDF5 **Blosc** filter, so you must have `hdf5plugin` installed (it registers the filter for `h5py`).

# %%
from __future__ import annotations

from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import h5py

# Required for these files (Blosc-compressed datasets)
try:
    import hdf5plugin  # noqa: F401
except Exception as exc:
    raise ImportError(
        "Missing dependency: hdf5plugin. Install with: pip install hdf5plugin"
    ) from exc

RAW_DIR = Path('..') / 'data' / 'raw'
FILES = sorted([*RAW_DIR.glob('*.h5'), *RAW_DIR.glob('*.hdf5')])
assert FILES, f"No HDF5 files found under {RAW_DIR.resolve()}"
print('Found raw files:')
for fp in FILES:
    print(' -', fp.name)

# ---------------------------
# HDF5 helpers (robust, bounded)
# ---------------------------
DATASET_PATH = 'df/block0_values'  # confirmed layout for these files
AXIS0_PATH = 'df/axis0'            # feature index (length 2100)
AXIS1_PATH = 'df/axis1'            # event index  (length N_events)

def get_filter_info(dset: h5py.Dataset) -> list[tuple[int, str]]:
    """Return a list of (filter_id, filter_name) used by dataset."""
    out: list[tuple[int, str]] = []
    plist = dset.id.get_create_plist()
    n = plist.get_nfilters()
    for i in range(n):
        fid, _flags, _cd, name = plist.get_filter(i)
        # `name` can be bytes depending on backend
        if isinstance(name, (bytes, bytearray)):
            name_s = name.decode('utf-8', errors='replace')
        else:
            name_s = str(name)
        out.append((int(fid), name_s))
    return out

def inspect_file(fp: Path) -> dict:
    """Open an LHCO file and return metadata we care about."""
    with h5py.File(fp, 'r') as f:
        if DATASET_PATH not in f:
            raise KeyError(f"Expected '{DATASET_PATH}' not found in {fp.name}. Root keys={list(f.keys())}")
        dset = f[DATASET_PATH]
        info = {
            'file': fp.name,
            'path': DATASET_PATH,
            'shape': tuple(int(x) for x in dset.shape),
            'dtype': str(dset.dtype),
            'chunks': dset.chunks,
            'compression': dset.compression,
            'filters': get_filter_info(dset),
        }
        return info

meta = pd.DataFrame([inspect_file(fp) for fp in FILES])
display(meta)

# ---------------------------
# Load a sample (memory-safe)
# ---------------------------
# Choose which file to explore
FILE_IDX = 0  # change 0..len(FILES)-1
fp = FILES[FILE_IDX]

# Keep this modest; raw is 2100 float64 per event.
N_EVENTS = 50_000  # adjust (e.g., 10_000 / 50_000 / 200_000)
DTYPE = np.float32

with h5py.File(fp, 'r') as f:
    dset = f[DATASET_PATH]
    n_total = int(dset.shape[0])
    n = min(int(N_EVENTS), n_total)
    X_raw = np.asarray(dset[:n], dtype=DTYPE)

print(f"Loaded {X_raw.shape[0]:,}/{n_total:,} events from {fp.name} as {X_raw.dtype} with shape {X_raw.shape}.")

# Convenience: reshape 2100 → (700, 3) when possible
if X_raw.shape[1] % 3 == 0:
    n_particles = X_raw.shape[1] // 3
    particles = X_raw.reshape(X_raw.shape[0], n_particles, 3)
    print('Interpreting as (pt, eta, phi) with n_particles =', n_particles)
    pt = particles[..., 0]
    eta = particles[..., 1]
    phi = particles[..., 2]
else:
    particles = None
    pt = eta = phi = None
    print('Column count not divisible by 3; skipping (pt,eta,phi) reshape.')
# Out:
# Found raw files:
#  - events_LHCO2020_backgroundMC_Pythia.h5
#  - events_LHCO2020_BlackBox1.h5
#  - events_LHCO2020_BlackBox2.h5
#  - events_LHCO2020_BlackBox3.h5
#                                      file              path            shape  \
# 0  events_LHCO2020_backgroundMC_Pythia.h5  df/block0_values  (1000000, 2100)
# 1            events_LHCO2020_BlackBox1.h5  df/block0_values  (1000000, 2100)
# 2            events_LHCO2020_BlackBox2.h5  df/block0_values  (1000000, 2100)
# 3            events_LHCO2020_BlackBox3.h5  df/block0_values  (1000000, 2100)
#
#      dtype      chunks compression           filters
# 0  float64  (62, 2100)        None  [(32001, blosc)]
# 1  float64  (62, 2100)        None  [(32001, blosc)]
# 2  float64  (62, 2100)        None  [(32001, blosc)]
# 3  float64  (62, 2100)        None  [(32001, blosc)]
# Loaded 50,000/1,000,000 events from events_LHCO2020_backgroundMC_Pythia.h5 as float32 with shape (50000, 2100).
# ...

# %% [markdown]
# ## Data quality checks

# %%
# Basic checks on the loaded sample
assert np.isfinite(X_raw).all(), "Found NaN/Inf values in X_raw"
print('X_raw summary:')
print('  min/max:', float(X_raw.min()), float(X_raw.max()))
print('  mean/std:', float(X_raw.mean()), float(X_raw.std()))

if particles is not None:
    # Presence mask: pt > 0 is a common convention for padded particle lists
    present = pt > 0
    mult = present.sum(axis=1)
    print('\nInterpreted particle-level stats:')
    print('  multiplicity: mean=', float(mult.mean()), 'std=', float(mult.std()), 'min=', int(mult.min()), 'max=', int(mult.max()))

    nonzero_pt = pt[present]
    print('  nonzero pt: count=', int(nonzero_pt.size), 'min=', float(nonzero_pt.min()), 'p50=', float(np.median(nonzero_pt)), 'max=', float(nonzero_pt.max()))

    # Quick sanity checks on ranges
    print('\nRanges (nonzero only):')
    eta_nz = eta[present]
    phi_nz = phi[present]
    print('  eta: min/max =', float(eta_nz.min()), float(eta_nz.max()))
    print('  phi: min/max =', float(phi_nz.min()), float(phi_nz.max()))
else:
    print('No particle reshape; consider exploring columns directly.')
# Out:
# X_raw summary:
#   min/max: -4.999996185302734 2614.868896484375
#   mean/std: 1.3789902925491333 15.989758491516113
#
# Interpreted particle-level stats:
#   multiplicity: mean= 182.0359 std= 61.00800284544643 min= 37 max= 475
#   nonzero pt: count= 9101795 min= 0.03176794946193695 p50= 3.169977903366089 max= 2614.868896484375
#
# Ranges (nonzero only):
#   eta: min/max = -4.999996185302734 4.999980449676514
#   phi: min/max = -3.1415913105010986 3.141592502593994

# %% [markdown]
# ## Visual diagnostics (histograms, heatmaps, correlations)

# %%
if particles is None:
    raise RuntimeError('Expected 2100 columns divisible by 3 to plot particle-level diagnostics.')

# Event-level summary features (cheap + useful)
present = pt > 0
mult = present.sum(axis=1).astype(np.int32)
leading_pt = np.where(mult > 0, pt.max(axis=1), 0.0).astype(np.float32)
sum_pt = pt.sum(axis=1).astype(np.float32)

# Nonzero means/stds (avoid dividing by 0)
pt_sum_nz = np.where(mult > 0, pt.sum(axis=1), 0.0)
pt2_sum_nz = np.where(mult > 0, (pt**2).sum(axis=1), 0.0)
mean_pt_nz = (pt_sum_nz / np.maximum(mult, 1)).astype(np.float32)
std_pt_nz = np.sqrt(np.maximum(pt2_sum_nz / np.maximum(mult, 1) - mean_pt_nz**2, 0.0)).astype(np.float32)

eta_sum_nz = np.where(mult > 0, (eta * present).sum(axis=1), 0.0)
eta2_sum_nz = np.where(mult > 0, ((eta**2) * present).sum(axis=1), 0.0)
mean_eta_nz = (eta_sum_nz / np.maximum(mult, 1)).astype(np.float32)
std_eta_nz = np.sqrt(np.maximum(eta2_sum_nz / np.maximum(mult, 1) - mean_eta_nz**2, 0.0)).astype(np.float32)

mean_abs_eta = (np.where(mult > 0, (np.abs(eta) * present).sum(axis=1) / np.maximum(mult, 1), 0.0)).astype(np.float32)

summary = pd.DataFrame({
    'multiplicity': mult,
    'leading_pt': leading_pt,
    'sum_pt': sum_pt,
    'mean_pt_nz': mean_pt_nz,
    'std_pt_nz': std_pt_nz,
    'mean_eta_nz': mean_eta_nz,
    'std_eta_nz': std_eta_nz,
    'mean_abs_eta': mean_abs_eta,
})
display(summary.describe().T)

# --- Figure 1: multiplicity and pT summaries ---
fig, axes = plt.subplots(2, 2, figsize=(12, 9))
axes = axes.ravel()

axes[0].hist(mult, bins=80, color='slateblue', alpha=0.8)
axes[0].set_title('Particle multiplicity per event')
axes[0].set_xlabel('N(particles)')
axes[0].set_ylabel('Events')

axes[1].hist(leading_pt, bins=80, color='teal', alpha=0.8, log=True)
axes[1].set_title('Leading particle $p_T$')
axes[1].set_xlabel('$p_T$')
axes[1].set_ylabel('Events (log)')

# Flatten nonzero pt but cap total points to keep memory stable
nonzero_pt = pt[present]
if nonzero_pt.size > 2_000_000:
    nonzero_pt = np.random.default_rng(42).choice(nonzero_pt, size=2_000_000, replace=False)
axes[2].hist(nonzero_pt, bins=120, color='darkorange', alpha=0.8, log=True)
axes[2].set_title('Nonzero particle $p_T$ (pooled)')
axes[2].set_xlabel('$p_T$')
axes[2].set_ylabel('Counts (log)')

axes[3].scatter(summary['multiplicity'], summary['sum_pt'], s=6, alpha=0.25, color='black')
axes[3].set_title('Event activity: $\\Sigma p_T$ vs multiplicity')
axes[3].set_xlabel('Multiplicity')
axes[3].set_ylabel('$\\Sigma p_T$')
axes[3].grid(alpha=0.2)

plt.tight_layout()

# --- Figure 2: eta-phi occupancy heatmap ---
eta_nz = eta[present]
phi_nz = phi[present]
if eta_nz.size > 2_000_000:
    rng = np.random.default_rng(123)
    sel = rng.choice(np.arange(eta_nz.size), size=2_000_000, replace=False)
    eta_nz = eta_nz[sel]
    phi_nz = phi_nz[sel]

plt.figure(figsize=(10, 4.5))
plt.hist2d(phi_nz, eta_nz, bins=(120, 120), cmap='viridis')
plt.colorbar(label='Counts')
plt.title('Particle occupancy in $(\\phi, \\eta)$ (nonzero only)')
plt.xlabel('$\\phi$')
plt.ylabel('$\\eta$')
plt.tight_layout()

# --- Figure 3: correlation heatmap (event-level summaries) ---
corr = summary.corr(numeric_only=True)
plt.figure(figsize=(7.5, 6))
plt.imshow(corr.values, cmap='coolwarm', vmin=-1, vmax=1)
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha='right')
plt.yticks(range(len(corr.index)), corr.index)
plt.colorbar(label='Pearson r')
plt.title('Event-level feature correlations')
plt.tight_layout()

# --- Figure 4: PCA projection of event-level summaries ---
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X_sum = summary.values.astype(np.float32)
X_sum = StandardScaler().fit_transform(X_sum)
Z = PCA(n_components=2, random_state=42).fit_transform(X_sum)

plt.figure(figsize=(6, 5))
plt.scatter(Z[:, 0], Z[:, 1], s=6, alpha=0.35, color='steelblue')
plt.title('PCA of event-level summaries')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.tight_layout()
# Out:
# <>:60: SyntaxWarning: invalid escape sequence '\S'
# <>:62: SyntaxWarning: invalid escape sequence '\S'
# <>:79: SyntaxWarning: invalid escape sequence '\p'
# <>:80: SyntaxWarning: invalid escape sequence '\p'
# <>:81: SyntaxWarning: invalid escape sequence '\e'
# <>:60: SyntaxWarning: invalid escape sequence '\S'
# <>:62: SyntaxWarning: invalid escape sequence '\S'
# <>:79: SyntaxWarning: invalid escape sequence '\p'
# <>:80: SyntaxWarning: invalid escape sequence '\p'
# <>:81: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\Pc\AppData\Local\Temp\ipykernel_24460\2883668373.py:60: SyntaxWarning: invalid escape sequence '\S'
#   axes[3].set_title('Event activity: $\Sigma p_T$ vs multiplicity')
# C:\Users\Pc\AppData\Local\Temp\ipykernel_24460\2883668373.py:62: SyntaxWarning: invalid escape sequence '\S'
#   axes[3].set_ylabel('$\Sigma p_T$')
# C:\Users\Pc\AppData\Local\Temp\ipykernel_24460\2883668373.py:79: SyntaxWarning: invalid escape sequence '\p'
# ...

# %% [markdown]
# ## Quick cross-file comparison (background vs blackboxes)

# %%
# Compare simple event-level summaries across files using a small slice from each.
# This is intentionally lightweight (no full loads).

COMPARE_N = 20_000
COMPARE_START = 0

rows = []
for fp_ in FILES:
    with h5py.File(fp_, 'r') as f:
        dset = f[DATASET_PATH]
        n_total = int(dset.shape[0])
        n = min(COMPARE_N, n_total - COMPARE_START)
        x = np.asarray(dset[COMPARE_START:COMPARE_START+n], dtype=np.float32)
        p = x.reshape(x.shape[0], x.shape[1]//3, 3)
        pt_ = p[..., 0]
        present_ = pt_ > 0
        mult_ = present_.sum(axis=1)
        lead_ = pt_.max(axis=1)
        sum_ = pt_.sum(axis=1)
    rows.append({
        'file': fp_.name,
        'multiplicity': mult_,
        'leading_pt': lead_,
        'sum_pt': sum_,
    })

# Overlay multiplicity distributions
plt.figure(figsize=(10, 4))
for r in rows:
    plt.hist(r['multiplicity'], bins=80, histtype='step', linewidth=2, density=True, label=r['file'].replace('events_LHCO2020_', '').replace('.h5',''))
plt.title('Multiplicity comparison (density)')
plt.xlabel('N(particles)')
plt.ylabel('Density')
plt.legend(fontsize=8)
plt.grid(alpha=0.2)
plt.tight_layout()

# Overlay leading-pt distributions
plt.figure(figsize=(10, 4))
for r in rows:
    plt.hist(r['leading_pt'], bins=80, histtype='step', linewidth=2, density=True, label=r['file'].replace('events_LHCO2020_', '').replace('.h5',''))
plt.yscale('log')
plt.title('Leading $p_T$ comparison (log-y, density)')
plt.xlabel('$p_T$')
plt.ylabel('Density (log)')
plt.legend(fontsize=8)
plt.grid(alpha=0.2)
plt.tight_layout()

# %%
# Optional: quick comparison helper
# Re-run the loading cell above with different FILE_IDX values to compare files.
# For scripted comparisons across all files, you can wrap the load+summary logic into a loop,
# but keep N_EVENTS modest to avoid long runtimes on 2–3 GB HDF5 files.
print('Exploration notebook ready. Adjust FILE_IDX and N_EVENTS, then re-run.')
# Out:
# Exploration notebook ready. Adjust FILE_IDX and N_EVENTS, then re-run.
